# %% [markdown]
# ## This notebook implements a streaming architecture:
#
# Producer: Fetches live data from OpenSky and publishes it to a Google Cloud Pub/Sub Topic.
#
# Consumer: Pulls messages from the Pub/Sub Subscription, streams them into a new BigQuery table (realtime_flight_data), and immediately runs predictions using your existing BQML models.

# %% [markdown]
# ## 1. Setup and Authentication

# %% [markdown]
# Context: Installs necessary Google Cloud libraries and handles Colab authentication.
#
# Prompt: "Write a Python code block for Google Colab that performs the following:
#
# Installs the google-cloud-pubsub, google-cloud-bigquery, google-cloud-storage, and requests libraries via pip.
#
# Imports auth from google.colab and authenticates the user to the Google Cloud environment."

# %%
# Install required packages
# !pip install google-cloud-pubsub google-cloud-bigquery google-cloud-storage requests

from google.colab import auth
print("Authenticating to Google Cloud...")
auth.authenticate_user()
print("Authentication successful.")
# Out:
# Requirement already satisfied: google-cloud-pubsub in /usr/local/lib/python3.12/dist-packages (2.33.0)
# Requirement already satisfied: google-cloud-bigquery in /usr/local/lib/python3.12/dist-packages (3.38.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.76.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (2.38.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (2.28.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (5.29.5)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (0.14.3)
# Requirement already satisfied: grpcio-status>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.71.2)
# Requirement already satisfied: opentelemetry-api>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk>=1.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-pubsub) (1.37.0)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.7.2)
# Requirement already satisfied: packaging>=24.2.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (25.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0,>=1.34.0->google-cloud-pubsub) (1.72.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (4.9.1)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio<2.0.0,>=1.51.3->google-cloud-pubsub) (4.15.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.27.0->google-cloud-pubsub) (8.7.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.27.0->google-cloud-pubsub) (0.58b0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.27.0->google-cloud-pubsub) (3.23.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-pubsub) (0.6.1)
# Authenticating to Google Cloud...
# Authentication successful.

# %% [markdown]
# ## Cell 2: Configuration Variables

# %% [markdown]
# Context: Defines global variables for Project ID, Pub/Sub resources, and BigQuery resources.
#
# Prompt: "Create a configuration cell that defines Python variables for a Google Cloud project. Specifically, define:
#
# PROJECT_ID (e.g., 'mgmt-467-47888')
#
# REGION (e.g., 'us-central1')
#
# TOPIC_NAME (e.g., 'opensky-realtime-topic')
#
# SUBSCRIPTION_NAME (e.g., 'opensky-realtime-sub')
#
# BQ_DATASET (e.g., 'training_dataset')
#
# BQ_TABLE_REALTIME (e.g., 'realtime_flight_data')
#
# MODEL_NAME (e.g., 'flight_velocity_predictor')
#
# Finally, execute a shell command to set the gcloud config project to the defined PROJECT_ID."

# %%
# --- Configuration ---
PROJECT_ID = "mgmt-467-nh"
REGION = "us-central1"

# Pub/Sub Configuration
TOPIC_NAME = "opensky-realtime-topic"
SUBSCRIPTION_NAME = "opensky-realtime-sub"

# BigQuery Configuration
BQ_DATASET = "opensky"
BQ_TABLE_REALTIME = "realtime_flight_data" # New table for streaming data
MODEL_NAME = "flight_velocity_predictor"   # The model we made in Unit 3.2

# Set the project for gcloud commands
# !gcloud config set project $PROJECT_ID
# Out:
# INFORMATION: Project 'mgmt-467-nh' has no 'environment' tag set. Use either 'Production', 'Development', 'Test', or 'Staging'. Add an 'environment' tag using `gcloud resource-manager tags bindings create`.
# Updated property [core/project].

# %% [markdown]
# ## Cell 3: Infrastructure Setup (Idempotent)

# %% [markdown]
# Context: Uses Python clients to create the Topic, Subscription, Dataset, and Table if they don't already exist.
#
# Prompt: "Write a Python script using the Google Cloud SDK (google.cloud) to set up infrastructure idempotently. The script should:
#
# Initialize Pub/Sub and BigQuery clients.
#
# Create a Pub/Sub Topic if it doesn't exist.
#
# Create a Pub/Sub Subscription to that topic if it doesn't exist.
#
# Create a BigQuery Dataset if it doesn't exist.
#
# Create a BigQuery Table named realtime_flight_data if it doesn't exist.
#
# Use a schema for the table that includes fields for OpenSky data: icao24 (STRING), callsign (STRING), origin_country (STRING), time_position (INTEGER), longitude (FLOAT), latitude (FLOAT), geo_altitude (FLOAT), on_ground (BOOLEAN), velocity (FLOAT), heading (FLOAT), vertical_rate (FLOAT), and sensor_timestamp (TIMESTAMP). Handle AlreadyExists exceptions gracefully."

# %%
from google.cloud import pubsub_v1, bigquery
from google.api_core.exceptions import NotFound, AlreadyExists

# Initialize clients
publisher_client = pubsub_v1.PublisherClient()
subscriber_client = pubsub_v1.SubscriberClient()
bq_client = bigquery.Client()

# Construct full resource paths
topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME)
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)

# 1. Create Pub/Sub Topic if it doesn't exist
print(f"Checking Pub/Sub Topic: {TOPIC_NAME}...")
try:
    publisher_client.get_topic(request={"topic": topic_path})
    print(f"Topic {TOPIC_NAME} already exists.")
except NotFound:
    try:
        publisher_client.create_topic(request={"name": topic_path})
        print(f"Topic {TOPIC_NAME} created.")
    except AlreadyExists:
        print(f"Topic {TOPIC_NAME} already exists (concurrent creation).")

# 2. Create Pub/Sub Subscription if it doesn't exist
print(f"Checking Pub/Sub Subscription: {SUBSCRIPTION_NAME}...")
try:
    subscriber_client.get_subscription(request={"subscription": subscription_path})
    print(f"Subscription {SUBSCRIPTION_NAME} already exists.")
except NotFound:
    try:
        # The topic must exist before creating a subscription to it
        subscriber_client.create_subscription(
            request={"name": subscription_path, "topic": topic_path}
        )
        print(f"Subscription {SUBSCRIPTION_NAME} created.")
    except AlreadyExists:
        print(f"Subscription {SUBSCRIPTION_NAME} already exists (concurrent creation).")

# 3. Create BigQuery Dataset if it doesn't exist
dataset_id = f"{PROJECT_ID}.{BQ_DATASET}"
dataset = bigquery.Dataset(dataset_id)

print(f"Checking BigQuery Dataset: {BQ_DATASET}...")
try:
    bq_client.get_dataset(dataset_id)
    print(f"Dataset {BQ_DATASET} already exists.")
except NotFound:
    try:
        dataset = bq_client.create_dataset(dataset)
        print(f"Dataset {BQ_DATASET} created.")
    except AlreadyExists:
        print(f"Dataset {BQ_DATASET} already exists (concurrent creation).")

# 4. Create BigQuery Table if it doesn't exist
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

# Define the schema for the realtime_flight_data table
schema = [
    bigquery.SchemaField("icao24", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("callsign", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("origin_country", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("time_position", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("last_contact", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("longitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("latitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("baro_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("geo_altitude", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("on_ground", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("velocity", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("heading", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("vertical_rate", "FLOAT", mode="NULLABLE"),
    bigquery.SchemaField("squawk", "STRING", mode="NULLABLE"),
    bigquery.SchemaField("spi", "BOOLEAN", mode="NULLABLE"),
    bigquery.SchemaField("position_source", "INTEGER", mode="NULLABLE"),
    bigquery.SchemaField("sensor_timestamp", "TIMESTAMP", mode="NULLABLE"), # Timestamp for when the data was processed
]

table = bigquery.Table(table_id, schema=schema)

print(f"Checking BigQuery Table: {BQ_TABLE_REALTIME}...")
try:
    bq_client.get_table(table_id)
    print(f"Table {BQ_TABLE_REALTIME} already exists.")
except NotFound:
    try:
        table = bq_client.create_table(table)
        print(f"Table {BQ_TABLE_REALTIME} created.")
    except AlreadyExists:
        print(f"Table {BQ_TABLE_REALTIME} already exists (concurrent creation).")

print("All required Google Cloud resources are ready.")
# Out:
# Checking Pub/Sub Topic: opensky-realtime-topic...
# Topic opensky-realtime-topic created.
# Checking Pub/Sub Subscription: opensky-realtime-sub...
# Subscription opensky-realtime-sub created.
# Checking BigQuery Dataset: opensky...
# Dataset opensky already exists.
# Checking BigQuery Table: realtime_flight_data...
# Table realtime_flight_data created.
# All required Google Cloud resources are ready.

# %% [markdown]
# ## Cell 4: OpenSky API Class Helper

# %% [markdown]
# Context: A helper class to interact with the REST API.
#
# Prompt: "Write a Python class named OpenSkyApi. The constructor should accept a username and password. Include a method named get_states that accepts bounding box coordinates (lmin, lmax, hmin, hmax) or an icao24 code. The method should make a GET request to https://opensky-network.org/api/states/all and return the list of flight states from the JSON response."

# %%
import requests
from collections import defaultdict

OPEN_SKY_USERNAME = "none"
OPEN_SKY_PASSWORD = "none"

class OpenSkyApi(object):
    def __init__(self, username, password):
        self._auth = (username, password)
        self._api_url = "https://opensky-network.org/api"
        self._last_requests = defaultdict(lambda: 0)

    def get_states(self, icao24=None, time_sec=None, lmin=None, lmax=None, hmin=None, hmax=None):
        params = {}
        if icao24:
            params['icao24'] = icao24
        if time_sec:
            params['time'] = time_sec
        if lmin is not None:
            params['lamin'] = lmin
        if lmax is not None:
            params['lamax'] = lmax
        if hmin is not None:
            params['lomin'] = hmin
        if hmax is not None:
            params['lomax'] = hmax

        try:
            response = requests.get(f"{self._api_url}/states/all",
                                    params=params,
                                    auth=self._auth)
            response.raise_for_status()
            data = response.json()
            return data.get('states', [])
        except requests.exceptions.RequestException as e:
            print(f"Error fetching OpenSky data: {e}")
            return []

# %% [markdown]
# ## 5. Data Processing and Publishing Function
#
# Context: Parses API data, cleans it, and pushes JSON messages to Pub/Sub.
#
# Prompt: "Create a function named process_and_publish that takes an OpenSky API response, a Pub/Sub publisher client, and a topic path.
#
# The function should:
#
# Iterate through the flight states.
#
# Map the raw list data to a dictionary with keys matching a BigQuery schema (icao24, callsign, longitude, latitude, velocity, geo_altitude, etc.).
#
# Add a current UTC timestamp field named sensor_timestamp.
#
# Filter out any records where velocity or geo_altitude are None.
#
# Publish the valid records as JSON strings to the Pub/Sub topic.
#
# Return the count of published messages."

# %%
import json
import datetime
from google.cloud import pubsub_v1

publisher_client = pubsub_v1.PublisherClient() # Re-initialize client if not globally available after split

def process_and_publish(api_response, publisher_client, topic_path):
    """Parses API response and publishes each flight as a Pub/Sub message, then cleans and filters."""
    if not api_response or 'states' not in api_response or api_response['states'] is None:
        print("No flight data received from OpenSky API.")
        return 0

    published_count = 0
    current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

    for state_vector in api_response['states']:
        data = {
            "icao24": state_vector[0],
            "callsign": state_vector[1].strip() if state_vector[1] else None,
            "origin_country": state_vector[2].strip() if state_vector[2] else None,
            "time_position": state_vector[3],
            "last_contact": state_vector[4],
            "longitude": state_vector[5],
            "latitude": state_vector[6],
            "baro_altitude": state_vector[7],
            "geo_altitude": state_vector[13],
            "on_ground": state_vector[8],
            "velocity": state_vector[9],
            "heading": state_vector[10],
            "vertical_rate": state_vector[11],
            "squawk": state_vector[14] if len(state_vector) > 14 else None,
            "spi": state_vector[15] if len(state_vector) > 15 else None,
            "position_source": state_vector[16] if len(state_vector) > 16 else None,
            "sensor_timestamp": current_utc_timestamp,
        }

        if data['velocity'] is not None and data['geo_altitude'] is not None:
            message_json_string = json.dumps(data)
            message_bytes = message_json_string.encode("utf-8")
            future = publisher_client.publish(topic_path, message_bytes)
            published_count += 1
        else:
            print(f"Skipping record due to missing velocity or geo_altitude for icao24: {state_vector[0]}")
    return published_count

# %% [markdown]
# ## 6. Subscriber and Prediction Function
# Context: Pulls messages, inserts to BQ, and runs an ML.PREDICT query immediately.
#
# Prompt: "Write a function named pull_and_insert_and_predict that runs for a specified timeout period.
#
# Inside the function:
#
# Subscribe to the Pub/Sub subscription.
#
# When a message is received, parse the JSON data.
#
# Insert the row immediately into the BigQuery table realtime_flight_data.
#
# Upon successful insertion, run a BigQuery SQL query using ML.PREDICT with the model flight_velocity_predictor. The query should predict the velocity for the specific flight (identified by icao24 and sensor_timestamp) that was just inserted.
#
# Print the prediction results and acknowledge the Pub/Sub message."

# %%
import google.cloud.pubsub_v1 as pubsub_v1_module
import google.cloud.bigquery as bigquery_module
from concurrent.futures import TimeoutError
import pandas as pd # Import pandas for DataFrame conversion

subscriber_client = pubsub_v1_module.SubscriberClient() # Re-initialize client if not globally available after split
bq_client = bigquery_module.Client(project=PROJECT_ID) # Explicitly pass PROJECT_ID here

# Define resource paths/IDs within this cell for reliability
subscription_path = subscriber_client.subscription_path(PROJECT_ID, SUBSCRIPTION_NAME)
table_id = f"{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}"

def pull_and_insert_and_predict(timeout=60):
    """Pulls messages from Pub/Sub, inserts into BigQuery, and runs BQML prediction.
    Returns a list of prediction results.
    """
    all_predictions = [] # List to store all prediction results

    def callback(message):
        print(f"Received message: {message.data.decode('utf-8')}")
        try:
            data_json = json.loads(message.data.decode('utf-8'))

            rows_to_insert = [data_json]
            errors = bq_client.insert_rows_json(table_id, rows_to_insert)

            if errors:
                print(f"Errors occurred during BigQuery insert: {errors}")
            else:
                print(f"Successfully inserted row for icao24={data_json.get('icao24')} into {table_id}")

                predict_query = f"""
                SELECT
                    *
                FROM
                    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{MODEL_NAME}`,
                        (SELECT
                            geo_altitude AS altitude, # Alias geo_altitude to altitude
                            vertical_rate,
                            heading
                         FROM
                            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
                         WHERE
                            icao24 = '{data_json['icao24']}'
                            AND sensor_timestamp = TIMESTAMP('{data_json['sensor_timestamp']}')
                         LIMIT 1))
                """
                predict_job = bq_client.query(predict_query)
                prediction_results = predict_job.result()

                for row in prediction_results:
                    prediction_dict = dict(row.items()) # Convert Row object to dictionary
                    all_predictions.append(prediction_dict) # Store the prediction result
                    print(f"BQML Prediction for icao24 {data_json['icao24']}: {prediction_dict}")
        except Exception as e:
            print(f"Error processing message or during BQML prediction: {e}")
        finally:
            message.ack()

    streaming_pull_future = subscriber_client.subscribe(subscription_path, callback=callback)
    print(f"Listening for messages on {subscription_path}... (Timeout: {timeout} seconds)\n")

    try:
        streaming_pull_future.result(timeout=timeout)
    except TimeoutError:
        streaming_pull_future.cancel()
        streaming_pull_future.result()
        print("Listening timed out. No messages received within the specified duration.")
    except Exception as e:
        print(f"An error occurred during streaming pull: {e}")
        streaming_pull_future.cancel()
        streaming_pull_future.result()

    return all_predictions

# %% [markdown]
# ## 7. Main Execution (Publisher Loop)
#
# Context: Fetches live data and calls the publish function.
#
# Prompt: "Write a script to execute the pipeline.
#
# Initialize the OpenSkyApi client (using placeholder credentials if necessary).
#
# Call the API to get flight states for a bounding box around Los Angeles (approx lat 34.0 to 34.5, lon -118.5 to -118.0).
#
# Initialize the Pub/Sub publisher client.
#
# Call the process_and_publish function to send the data to Pub/Sub.
#
# Print the number of messages successfully published."

# %%
print("Fetching flight data from OpenSky and publishing to Pub/Sub...")

# Ensure configuration variables are accessible
# TOPIC_ID, PROJECT_ID, OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD are expected to be defined globally
#TOPIC_NAME = TOPIC_ID # Aligning with how other functions expect TOPIC_NAME

# Initialize OpenSky API client
opensky_api = OpenSkyApi(OPEN_SKY_USERNAME, OPEN_SKY_PASSWORD)

# Fetch states for a specific region (e.g., around a major airport)
# Adjust these coordinates as needed for your desired coverage area
lmin = 34.0
lmax = 34.5
hmin = -118.5
hmax = -118.0

states = opensky_api.get_states(lmin=lmin, lmax=lmax, hmin=hmin, hmax=hmax)

if states:
    # Initialize publisher client (if not already done globally)
    publisher_client = pubsub_v1.PublisherClient()

    # Topic path is already defined from configuration cell
    topic_path = publisher_client.topic_path(PROJECT_ID, TOPIC_NAME) # Using the now-defined TOPIC_NAME

    published_count = process_and_publish({'states': states}, publisher_client, topic_path)
    print(f"Successfully published {published_count} messages to Pub/Sub topic {TOPIC_NAME}.")
else:
    print("No states received from OpenSky API or an error occurred. No messages published.")
# Out:
# Fetching flight data from OpenSky and publishing to Pub/Sub...
# Skipping record due to missing velocity or geo_altitude for icao24: a60409
# Skipping record due to missing velocity or geo_altitude for icao24: a2d926
# Skipping record due to missing velocity or geo_altitude for icao24: a7767b
# Skipping record due to missing velocity or geo_altitude for icao24: ab351f
# Skipping record due to missing velocity or geo_altitude for icao24: a0c1d7
# Skipping record due to missing velocity or geo_altitude for icao24: a7e58a
# Skipping record due to missing velocity or geo_altitude for icao24: a4835c
# Successfully published 7 messages to Pub/Sub topic opensky-realtime-topic.
# /tmp/ipython-input-230726547.py:14: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   current_utc_timestamp = datetime.datetime.utcnow().isoformat() + "Z"

# %% [markdown]
# ## 8. Main Execution (Subscriber/Predictor)
#
# Context: Runs the subscriber to process the data sent in the previous step.
#
# Prompt: "Write a code block to run the pull_and_insert_and_predict function with a timeout of 60 seconds. Capture the returned predictions into a Pandas DataFrame. If predictions exist, display the head of the DataFrame; otherwise, print that no messages were received."

# %%
print("Starting to pull messages and generate predictions...")
# Run the pull_and_insert_and_predict function and get the results
predictions_list = pull_and_insert_and_predict(timeout=60) # You can adjust the timeout as needed

if predictions_list:
    predictions_df = pd.DataFrame(predictions_list)
    print("\nBQML Prediction Results (DataFrame Head):")
    display(predictions_df.head())
else:
    print("No predictions were generated or received within the timeout period.")
# Out:
# Starting to pull messages and generate predictions...
# Listening for messages on projects/mgmt-467-nh/subscriptions/opensky-realtime-sub... (Timeout: 60 seconds)
#
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672754, "last_contact": 1763672755, "longitude": -118.1425, "latitude": 34.4227, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 233.17, "heading": 151.68, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672755, "last_contact": 1763672755, "longitude": -118.4224, "latitude": 34.1797, "baro_altitude": 1272.54, "geo_altitude": 1257.3, "on_ground": false, "velocity": 138.27, "heading": 330.1, "vertical_rate": 16.91, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672751, "last_contact": 1763672753, "longitude": -118.3377, "latitude": 34.0912, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 33.82, "heading": 236.79, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672755, "last_contact": 1763672755, "longitude": -118.3388, "latitude": 34.3369, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.08, "heading": 330.97, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# Received message: {"icao24": "a242e6", "callsign": "N245DJ", "origin_country": "United States", "time_position": 1763672755, "last_contact": 1763672755, "longitude": -118.355, "latitude": 34.1922, "baro_altitude": 434.34, "geo_altitude": 411.48, "on_ground": false, "velocity": 95.36, "heading": 167.54, "vertical_rate": 14.96, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672739, "last_contact": 1763672739, "longitude": -118.4206, "latitude": 34.0413, "baro_altitude": 220.98, "geo_altitude": 213.36, "on_ground": false, "velocity": 46.96, "heading": 227.22, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672739, "last_contact": 1763672739, "longitude": -118.1615, "latitude": 34.452, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.71, "heading": 151.62, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672739, "last_contact": 1763672739, "longitude": -118.406, "latitude": 34.1659, "baro_altitude": 1051.56, "geo_altitude": 1036.32, "on_ground": false, "velocity": 132.29, "heading": 296.57, "vertical_rate": 12.68, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672735, "last_contact": 1763672739, "longitude": -118.3322, "latitude": 34.0939, "baro_altitude": 320.04, "geo_altitude": 297.18, "on_ground": false, "velocity": 37.53, "heading": 241.33, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672739, "last_contact": 1763672739, "longitude": -118.0167, "latitude": 34.0453, "baro_altitude": 7589.52, "geo_altitude": 7658.1, "on_ground": false, "velocity": 139.94, "heading": 107.1, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a242e6 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.30935692419425, 'altitude': 1257.3, 'vertical_rate': 16.91, 'heading': 330.1}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672739, "last_contact": 1763672739, "longitude": -118.3295, "latitude": 34.3231, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.14, "heading": 330.36, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:42.890097Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.76553529065251, 'altitude': 297.18, 'vertical_rate': 0.0, 'heading': 236.79}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672754, "last_contact": 1763672754, "longitude": -118.4265, "latitude": 34.0365, "baro_altitude": 220.98, "geo_altitude": 205.74, "on_ground": false, "velocity": 46.58, "heading": 223.21, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:58.524011Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.5364891615984, 'altitude': 10713.72, 'vertical_rate': 0.0, 'heading': 151.62}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.008, "latitude": 34.043, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 140.59, "heading": 107.24, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.53225652222505, 'altitude': 10713.72, 'vertical_rate': 0.0, 'heading': 151.68}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3332, "latitude": 34.3286, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.3723899281878, 'altitude': 2103.12, 'vertical_rate': -0.33, 'heading': 330.97}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.4225, "latitude": 34.0398, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.52, "heading": 227.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.6739388800735, 'altitude': 7658.1, 'vertical_rate': 2.28, 'heading': 107.1}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672745, "longitude": -118.1548, "latitude": 34.4416, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# BQML Prediction for icao24 a242e6: {'predicted_velocity': 72.2004648726132, 'altitude': 411.48, 'vertical_rate': 14.96, 'heading': 167.54}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.413, "latitude": 34.1699, "baro_altitude": 1127.76, "geo_altitude": 1112.52, "on_ground": false, "velocity": 135.16, "heading": 309.75, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.34008149597545, 'altitude': 213.36, 'vertical_rate': -0.33, 'heading': 227.22}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3354, "latitude": 34.0924, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 36.26, "heading": 238.34, "vertical_rate": -0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:48.452835Z"}
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.44526557806957, 'altitude': 297.18, 'vertical_rate': 0.0, 'heading': 241.33}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672747, "longitude": -118.1523, "latitude": 34.4378, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.91969782174814, 'altitude': 1036.32, 'vertical_rate': 12.68, 'heading': 296.57}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672746, "longitude": -118.415, "latitude": 34.1714, "baro_altitude": 1150.62, "geo_altitude": 1143, "on_ground": false, "velocity": 136.44, "heading": 313.93, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.205612469282, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 227.53}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672746, "longitude": -118.3361, "latitude": 34.0921, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 35.83, "heading": 237.91, "vertical_rate": -1.63, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.27672009575001, 'altitude': 2103.12, 'vertical_rate': 0.0, 'heading': 330.73}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.0053, "latitude": 34.0423, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 141.23, "heading": 107.38, "vertical_rate": 1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.19022098195444, 'altitude': 2103.12, 'vertical_rate': 0.33, 'heading': 330.36}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.3341, "latitude": 34.3299, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "a242e6", "callsign": "N245DJ", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.3567, "latitude": 34.1985, "baro_altitude": 320.04, "geo_altitude": 281.94, "on_ground": false, "velocity": 84.76, "heading": 167.74, "vertical_rate": 13.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.98361265946129, 'altitude': 1112.52, 'vertical_rate': 13.0, 'heading': 309.75}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.4238, "latitude": 34.0388, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.85, "heading": 226.25, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a242e6 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.8846372969278, 'altitude': 7673.34, 'vertical_rate': 2.28, 'heading': 107.24}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672747, "longitude": -118.1523, "latitude": 34.4378, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.99058114360646, 'altitude': 297.18, 'vertical_rate': -0.98, 'heading': 238.34}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672746, "longitude": -118.415, "latitude": 34.1714, "baro_altitude": 1150.62, "geo_altitude": 1143, "on_ground": false, "velocity": 136.44, "heading": 313.93, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.51267560639782, 'altitude': 205.74, 'vertical_rate': -0.33, 'heading': 223.21}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672746, "last_contact": 1763672746, "longitude": -118.3361, "latitude": 34.0921, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 35.83, "heading": 237.91, "vertical_rate": -1.63, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.0053, "latitude": 34.0423, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 141.23, "heading": 107.38, "vertical_rate": 1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 73.12988793390254, 'altitude': 1143.0, 'vertical_rate': 13.0, 'heading': 313.93}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.3341, "latitude": 34.3299, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.38932048568118, 'altitude': 2103.12, 'vertical_rate': -0.33, 'heading': 330.73}
# Received message: {"icao24": "a242e6", "callsign": "N245DJ", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.3567, "latitude": 34.1985, "baro_altitude": 320.04, "geo_altitude": 281.94, "on_ground": false, "velocity": 84.76, "heading": 167.74, "vertical_rate": 13.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:02.494201Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 71.24270370594954, 'altitude': 297.18, 'vertical_rate': -1.63, 'heading': 237.91}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672748, "last_contact": 1763672748, "longitude": -118.4242, "latitude": 34.0385, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.48, "heading": 225.84, "vertical_rate": 0.65, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.98736152832117, 'altitude': 7673.34, 'vertical_rate': 1.95, 'heading': 107.38}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672748, "longitude": -118.416, "latitude": 34.1723, "baro_altitude": 1165.86, "geo_altitude": 1150.62, "on_ground": false, "velocity": 136.44, "heading": 316.07, "vertical_rate": 13.66, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.18330838598214, 'altitude': 213.36, 'vertical_rate': 0.33, 'heading': 226.25}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672748, "last_contact": 1763672748, "longitude": -118.3365, "latitude": 34.0918, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 35.67, "heading": 236.77, "vertical_rate": -1.3, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# BQML Prediction for icao24 a242e6: {'predicted_velocity': 70.86764986746881, 'altitude': 281.94, 'vertical_rate': 13.33, 'heading': 167.74}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.4225, "latitude": 34.0398, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.52, "heading": 227.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# Successfully inserted row for icao24=a242e6 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672748, "longitude": -118.1511, "latitude": 34.436, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.71, "heading": 151.62, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 71.24270370594954, 'altitude': 297.18, 'vertical_rate': -1.63, 'heading': 237.91}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672745, "longitude": -118.1548, "latitude": 34.4416, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 73.12988793390254, 'altitude': 1143.0, 'vertical_rate': 13.0, 'heading': 313.93}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.413, "latitude": 34.1699, "baro_altitude": 1127.76, "geo_altitude": 1112.52, "on_ground": false, "velocity": 135.16, "heading": 309.75, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.38932048568118, 'altitude': 2103.12, 'vertical_rate': -0.33, 'heading': 330.73}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3354, "latitude": 34.0924, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 36.26, "heading": 238.34, "vertical_rate": -0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.98736152832117, 'altitude': 7673.34, 'vertical_rate': 1.95, 'heading': 107.38}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.008, "latitude": 34.043, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 140.59, "heading": 107.24, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.205612469282, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 227.53}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3332, "latitude": 34.3286, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:01.676211Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 71.21052346411189, 'altitude': 297.18, 'vertical_rate': -1.3, 'heading': 236.77}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672748, "last_contact": 1763672748, "longitude": -118.0038, "latitude": 34.0419, "baro_altitude": 7612.38, "geo_altitude": 7680.96, "on_ground": false, "velocity": 141.23, "heading": 107.38, "vertical_rate": 1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# BQML Prediction for icao24 a242e6: {'predicted_velocity': 70.86764986746881, 'altitude': 281.94, 'vertical_rate': 13.33, 'heading': 167.74}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672748, "last_contact": 1763672748, "longitude": -118.3347, "latitude": 34.3307, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.08, "heading": 330.97, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.86401030408702, 'altitude': 1150.62, 'vertical_rate': 13.66, 'heading': 316.07}
# Received message: {"icao24": "a242e6", "callsign": "N245DJ", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672748, "longitude": -118.3567, "latitude": 34.1985, "baro_altitude": 320.04, "geo_altitude": 297.18, "on_ground": false, "velocity": 86.27, "heading": 167.95, "vertical_rate": 11.38, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:52.101912Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.4225, "latitude": 34.0398, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.52, "heading": 227.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.42388877166724, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.62}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672745, "longitude": -118.1548, "latitude": 34.4416, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# Successfully inserted row for icao24=a242e6 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.10304316479703, 'altitude': 213.36, 'vertical_rate': 0.65, 'heading': 225.84}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.413, "latitude": 34.1699, "baro_altitude": 1127.76, "geo_altitude": 1112.52, "on_ground": false, "velocity": 135.16, "heading": 309.75, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.98361265946129, 'altitude': 1112.52, 'vertical_rate': 13.0, 'heading': 309.75}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3354, "latitude": 34.0924, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 36.26, "heading": 238.34, "vertical_rate": -0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.99058114360646, 'altitude': 297.18, 'vertical_rate': -0.98, 'heading': 238.34}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.008, "latitude": 34.043, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 140.59, "heading": 107.24, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.8846372969278, 'altitude': 7673.34, 'vertical_rate': 2.28, 'heading': 107.24}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3332, "latitude": 34.3286, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.880062Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.27672009575001, 'altitude': 2103.12, 'vertical_rate': 0.0, 'heading': 330.73}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672734, "last_contact": 1763672734, "longitude": -118.3316, "latitude": 34.0942, "baro_altitude": 320.04, "geo_altitude": 297.18, "on_ground": false, "velocity": 37.98, "heading": 241.7, "vertical_rate": 0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.3723899281878, 'altitude': 2103.12, 'vertical_rate': -0.33, 'heading': 330.97}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672734, "last_contact": 1763672734, "longitude": -118.0242, "latitude": 34.0472, "baro_altitude": 7574.28, "geo_altitude": 7642.86, "on_ground": false, "velocity": 140.1, "heading": 107.3, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# BQML Prediction for icao24 a242e6: {'predicted_velocity': 71.73877614555659, 'altitude': 297.18, 'vertical_rate': 11.38, 'heading': 167.95}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672734, "last_contact": 1763672734, "longitude": -118.3269, "latitude": 34.3194, "baro_altitude": 2118.36, "geo_altitude": 2095.5, "on_ground": false, "velocity": 107.39, "heading": 330.12, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 186.0976488160172, 'altitude': 7680.96, 'vertical_rate': 1.95, 'heading': 107.38}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672733, "last_contact": 1763672734, "longitude": -118.4188, "latitude": 34.0428, "baro_altitude": 220.98, "geo_altitude": 205.74, "on_ground": false, "velocity": 48.02, "heading": 225.87, "vertical_rate": -2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.205612469282, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 227.53}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672734, "last_contact": 1763672734, "longitude": -118.1678, "latitude": 34.4616, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.71, "heading": 151.62, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.99058114360646, 'altitude': 297.18, 'vertical_rate': -0.98, 'heading': 238.34}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672734, "last_contact": 1763672734, "longitude": -118.3995, "latitude": 34.1637, "baro_altitude": 998.22, "geo_altitude": 982.98, "on_ground": false, "velocity": 128.78, "heading": 284.81, "vertical_rate": 8.78, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:38.411602Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672758, "last_contact": 1763672758, "longitude": -118.4277, "latitude": 34.0354, "baro_altitude": 213.36, "geo_altitude": 198.12, "on_ground": false, "velocity": 46.23, "heading": 222.75, "vertical_rate": -1.95, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.98361265946129, 'altitude': 1112.52, 'vertical_rate': 13.0, 'heading': 309.75}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672757, "last_contact": 1763672758, "longitude": -118.1394, "latitude": 34.4179, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 233.17, "heading": 151.68, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.8846372969278, 'altitude': 7673.34, 'vertical_rate': 2.28, 'heading': 107.24}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672758, "last_contact": 1763672758, "longitude": -118.4245, "latitude": 34.183, "baro_altitude": 1325.88, "geo_altitude": 1310.64, "on_ground": false, "velocity": 138.27, "heading": 333.24, "vertical_rate": 16.91, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.27672009575001, 'altitude': 2103.12, 'vertical_rate': 0.0, 'heading': 330.73}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672751, "last_contact": 1763672753, "longitude": -118.3377, "latitude": 34.0912, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 33.82, "heading": 236.79, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.08477526516866, 'altitude': 297.18, 'vertical_rate': 0.98, 'heading': 241.7}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672758, "last_contact": 1763672758, "longitude": -118.3404, "latitude": 34.3393, "baro_altitude": 2118.36, "geo_altitude": 2095.5, "on_ground": false, "velocity": 107.08, "heading": 330.97, "vertical_rate": -0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.43925550677028, 'altitude': 7642.86, 'vertical_rate': 2.28, 'heading': 107.3}
# Received message: {"icao24": "a242e6", "callsign": "N245DJ", "origin_country": "United States", "time_position": 1763672758, "last_contact": 1763672758, "longitude": -118.3545, "latitude": 34.1896, "baro_altitude": 480.06, "geo_altitude": 457.2, "on_ground": false, "velocity": 96.33, "heading": 171.09, "vertical_rate": 15.61, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:06:00.117032Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.64908955152958, 'altitude': 10713.72, 'vertical_rate': -0.33, 'heading': 151.62}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.4225, "latitude": 34.0398, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.52, "heading": 227.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a242e6 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.98760410446862, 'altitude': 198.12, 'vertical_rate': -1.95, 'heading': 222.75}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672745, "longitude": -118.1548, "latitude": 34.4416, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.64485691215623, 'altitude': 10713.72, 'vertical_rate': -0.33, 'heading': 151.68}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.413, "latitude": 34.1699, "baro_altitude": 1127.76, "geo_altitude": 1112.52, "on_ground": false, "velocity": 135.16, "heading": 309.75, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.99039453468201, 'altitude': 205.74, 'vertical_rate': -2.28, 'heading': 225.87}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3354, "latitude": 34.0924, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 36.26, "heading": 238.34, "vertical_rate": -0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.20946464168296, 'altitude': 2095.5, 'vertical_rate': 0.0, 'heading': 330.12}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.008, "latitude": 34.043, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 140.59, "heading": 107.24, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 74.30801600605582, 'altitude': 982.98, 'vertical_rate': 8.78, 'heading': 284.81}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3332, "latitude": 34.3286, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:50.720590Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.85985981086158, 'altitude': 1310.64, 'vertical_rate': 16.91, 'heading': 333.24}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.4225, "latitude": 34.0398, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.52, "heading": 227.53, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.76553529065251, 'altitude': 297.18, 'vertical_rate': 0.0, 'heading': 236.79}
# Received message: {"icao24": "a61797", "callsign": "ASA714", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672745, "longitude": -118.1548, "latitude": 34.4416, "baro_altitude": 10668, "geo_altitude": 10713.72, "on_ground": false, "velocity": 232.47, "heading": 151.73, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# Successfully inserted row for icao24=a61797 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.205612469282, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 227.53}
# Received message: {"icao24": "a038c0", "callsign": "JSX174", "origin_country": "United States", "time_position": 1763672744, "last_contact": 1763672744, "longitude": -118.413, "latitude": 34.1699, "baro_altitude": 1127.76, "geo_altitude": 1112.52, "on_ground": false, "velocity": 135.16, "heading": 309.75, "vertical_rate": 13, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# BQML Prediction for icao24 a242e6: {'predicted_velocity': 72.38996878903254, 'altitude': 457.2, 'vertical_rate': 15.61, 'heading': 171.09}
# Received message: {"icao24": "a5c983", "callsign": "N472LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3354, "latitude": 34.0924, "baro_altitude": 312.42, "geo_altitude": 297.18, "on_ground": false, "velocity": 36.26, "heading": 238.34, "vertical_rate": -0.98, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# Successfully inserted row for icao24=a038c0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.27672009575001, 'altitude': 2103.12, 'vertical_rate': 0.0, 'heading': 330.73}
# Received message: {"icao24": "a1e96a", "callsign": "N222LA", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.008, "latitude": 34.043, "baro_altitude": 7604.76, "geo_altitude": 7673.34, "on_ground": false, "velocity": 140.59, "heading": 107.24, "vertical_rate": 2.28, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.98361265946129, 'altitude': 1112.52, 'vertical_rate': 13.0, 'heading': 309.75}
# Received message: {"icao24": "a2f5d0", "callsign": "N290DL", "origin_country": "United States", "time_position": 1763672745, "last_contact": 1763672745, "longitude": -118.3332, "latitude": 34.3286, "baro_altitude": 2125.98, "geo_altitude": 2103.12, "on_ground": false, "velocity": 107.33, "heading": 330.73, "vertical_rate": 0, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:59.326534Z"}
# Successfully inserted row for icao24=a1e96a into mgmt-467-nh.opensky.realtime_flight_data
# Successfully inserted row for icao24=a5c983 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# Received message: {"icao24": "ae277c", "callsign": "GH08", "origin_country": "United States", "time_position": 1763672747, "last_contact": 1763672747, "longitude": -118.4238, "latitude": 34.0388, "baro_altitude": 228.6, "geo_altitude": 213.36, "on_ground": false, "velocity": 49.85, "heading": 226.25, "vertical_rate": 0.33, "squawk": null, "spi": false, "position_source": 0, "sensor_timestamp": "2025-11-20T21:05:57.665904Z"}
# Successfully inserted row for icao24=a2f5d0 into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.8846372969278, 'altitude': 7673.34, 'vertical_rate': 2.28, 'heading': 107.24}
# Successfully inserted row for icao24=ae277c into mgmt-467-nh.opensky.realtime_flight_data
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.205612469282, 'altitude': 213.36, 'vertical_rate': 0.0, 'heading': 227.53}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.99058114360646, 'altitude': 297.18, 'vertical_rate': -0.98, 'heading': 238.34}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.26210264049178, 'altitude': 2095.5, 'vertical_rate': -0.33, 'heading': 330.97}
# BQML Prediction for icao24 a61797: {'predicted_velocity': 227.4161289328161, 'altitude': 10713.72, 'vertical_rate': 0.33, 'heading': 151.73}
# BQML Prediction for icao24 a038c0: {'predicted_velocity': 72.98361265946129, 'altitude': 1112.52, 'vertical_rate': 13.0, 'heading': 309.75}
# BQML Prediction for icao24 a1e96a: {'predicted_velocity': 185.8846372969278, 'altitude': 7673.34, 'vertical_rate': 2.28, 'heading': 107.24}
# BQML Prediction for icao24 ae277c: {'predicted_velocity': 70.18330838598214, 'altitude': 213.36, 'vertical_rate': 0.33, 'heading': 226.25}
# BQML Prediction for icao24 a5c983: {'predicted_velocity': 70.99058114360646, 'altitude': 297.18, 'vertical_rate': -0.98, 'heading': 238.34}
# BQML Prediction for icao24 a2f5d0: {'predicted_velocity': 90.27672009575001, 'altitude': 2103.12, 'vertical_rate': 0.0, 'heading': 330.73}
# Listening timed out. No messages received within the specified duration.
#
# BQML Prediction Results (DataFrame Head):
#    predicted_velocity  altitude  vertical_rate  heading
# 0           72.309357   1257.30          16.91   330.10
# 1           70.765535    297.18           0.00   236.79
# 2          227.536489  10713.72           0.00   151.62
# 3          227.532257  10713.72           0.00   151.68
# 4           90.372390   2103.12          -0.33   330.97

# %% [markdown]
# ## 9. Visualization (Predicted vs Actual)
#
# Context: Scatter plot of the results.
#
# Prompt: "Using matplotlib and seaborn, write code to visualize the prediction results stored in the predictions_df DataFrame. Create a scatter plot where the x-axis is 'heading' and the y-axis is 'predicted_velocity'. Color the points based on the predicted velocity using a 'viridis' palette."

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'predictions_df' in locals() and not predictions_df.empty:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x='heading', y='predicted_velocity', data=predictions_df, hue='predicted_velocity', palette='viridis')
    plt.title('Predicted Velocity vs. Heading')
    plt.xlabel('Heading (degrees)')
    plt.ylabel('Predicted Velocity')
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()
else:
    print("predictions_df is not available or empty. Please ensure predictions are generated first.")

# %% [markdown]
# ## 10. Flight Path Query & Visualization
#
# Context: Queries historical data for a specific plane and plots the path.
#
# Prompt: "Write a code block that:
#
# Creates an input form field for CALLSIGN_TO_TRACK (defaulting to 'DAL339').
#
# Queries the BigQuery table realtime_flight_data to retrieve the longitude, latitude, geo_altitude, and velocity for that callsign, ordered by timestamp.
#
# Stores the result in a DataFrame.
#
# Uses Seaborn to plot a line chart of Longitude vs. Latitude to visualize the flight path.
#
# Mark the start position with a green dot and the end position with a red dot."

# %%
#@title Enter the Callsign to Track
CALLSIGN_TO_TRACK = 'N222LA' #@param {type:"string"}

print(f"You chose to track flight with Callsign: {CALLSIGN_TO_TRACK}")
# Out:
# You chose to track flight with Callsign: N222LA

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Fetching flight data for callsign: {CALLSIGN_TO_TRACK}...")

flight_path_query = f"""
SELECT
    sensor_timestamp,
    longitude,
    latitude,
    geo_altitude,
    velocity,
    heading,
    vertical_rate
FROM
    `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
WHERE
    callsign = '{CALLSIGN_TO_TRACK}'
ORDER BY
    sensor_timestamp ASC
"""

flight_path_job = bq_client.query(flight_path_query)
flight_path_df = flight_path_job.to_dataframe()

if not flight_path_df.empty:
    print(f"Found {len(flight_path_df)} records for {CALLSIGN_TO_TRACK}.")
    display(flight_path_df.head())
else:
    print(f"No flight data found for callsign: {CALLSIGN_TO_TRACK}")
# Out:
# Fetching flight data for callsign: N222LA...
# Found 13 records for N222LA.
#                   sensor_timestamp  longitude  latitude  geo_altitude  \
# 0 2025-11-20 21:01:26.351151+00:00  -118.4122   34.1490       6964.68
# 1 2025-11-20 21:01:27.332028+00:00  -118.3870   34.1423       7010.40
# 2 2025-11-20 21:01:28.503081+00:00  -118.3870   34.1423       7010.40
# 3 2025-11-20 21:05:38.411602+00:00  -118.0242   34.0472       7642.86
# 4 2025-11-20 21:05:42.890097+00:00  -118.0167   34.0453       7658.10
#
#    velocity  heading  vertical_rate
# 0    135.19   107.95           2.60
# 1    136.66   107.75           2.28
# 2    136.66   107.75           2.28
# 3    140.10   107.30           2.28
# 4    139.94   107.10           2.28

# %%
import matplotlib.pyplot as plt
import seaborn as sns

if 'flight_path_df' in locals() and not flight_path_df.empty:
    plt.figure(figsize=(12, 8))
    sns.lineplot(x='longitude', y='latitude', data=flight_path_df, marker='o', sort=False)
    plt.title(f'Flight Path for Callsign: {CALLSIGN_TO_TRACK}')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.grid(True, linestyle='--', alpha=0.7)

    # Optionally, add start and end points
    if len(flight_path_df) > 0:
        plt.plot(flight_path_df['longitude'].iloc[0], flight_path_df['latitude'].iloc[0], 'go', markersize=10, label='Start') # Green circle for start
        plt.plot(flight_path_df['longitude'].iloc[-1], flight_path_df['latitude'].iloc[-1], 'ro', markersize=10, label='End') # Red circle for end

    plt.legend()
    plt.show()
else:
    print("No flight path data available to plot.")
# Out:
# No flight path data available to plot.

# %% [markdown]
# ## 11. Classification Model Prediction
#
# Context: Using a different model to classify if a plane is on the ground.
#
# Prompt: "Write a script to perform classification using BigQuery ML.
#
# Define a model name flight_on_ground_classifier.
#
# Construct a SQL query that uses ML.PREDICT with this model.
#
# The input data for the prediction should be the most recent 100 records from the realtime_flight_data table (selecting icao24, geo_altitude, and velocity).
#
# Execute the query and display the classification results in a DataFrame."

# %%
# Define the classification model name
CLASSIFICATION_MODEL_NAME = "flight_on_ground_classifier"

print(f"Classification Model: {CLASSIFICATION_MODEL_NAME}")
# Out:
# Classification Model: flight_on_ground_classifier

# %%
from google.cloud import bigquery
import pandas as pd

bq_client = bigquery.Client(project=PROJECT_ID)

print(f"Running classification predictions using model: {CLASSIFICATION_MODEL_NAME}...")

# Construct the prediction query for the classification model
# We will use the latest data inserted into realtime_flight_data as input
classification_predict_query = f"""
SELECT
    * EXCEPT(predicted_on_ground_probs)
FROM
    ML.PREDICT(MODEL `{PROJECT_ID}.{BQ_DATASET}.{CLASSIFICATION_MODEL_NAME}`,
        (SELECT
            icao24,
            geo_altitude AS altitude, # Alias geo_altitude to altitude as required by model
            velocity
         FROM
            `{PROJECT_ID}.{BQ_DATASET}.{BQ_TABLE_REALTIME}`
         LIMIT 100 # Limit to avoid processing too much data for demonstration
         ))
"""

classification_predict_job = bq_client.query(classification_predict_query)
classification_predictions = classification_predict_job.result()

# Convert results to a Pandas DataFrame for easy viewing
classification_predictions_df = classification_predictions.to_dataframe()

if not classification_predictions_df.empty:
    print("\nBQML Classification Prediction Results (DataFrame Head):")
    display(classification_predictions_df.head())
else:
    print("No classification predictions were generated.")
# Out:
# Running classification predictions using model: flight_on_ground_classifier...
#
# BQML Classification Prediction Results (DataFrame Head):
#    predicted_on_ground  icao24  altitude  velocity
# 0                    0  a75abe    411.48     46.99
# 1                    0  a506d5   5036.82    163.12
# 2                    0  a0c1d7    396.24     57.33
# 3                    0  a299f9    220.98     56.63
# 4                    0  c080ae  11361.42    227.61
