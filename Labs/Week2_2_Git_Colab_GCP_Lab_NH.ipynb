# %% [markdown]
# # Week 2.2 Lab: GitHub + Colab + GCP Integration

# %% [markdown]
# In this guided lab, you will practice setting up your **team workflow** by connecting GitHub, Google Colab, Google Drive,
# and Google Cloud Platform (GCP). By the end, you will have a working notebook saved in your team repo and authenticated to GCP.
#
# **Learning Objectives:**
# - Create and configure a GitHub account (if not already done).
# - Create or join your **team repository** on GitHub.
# - Connect Colab to Google Drive for data and notebook persistence.
# - Authenticate Colab to access GCP services (BigQuery, Storage).
# - Save your Colab notebook to your GitHub repository.

# %% [markdown]
# ## 1. GitHub Account & Team Repository

# %% [markdown]
# 1. Go to [https://github.com](https://github.com) and create an account (if you don’t already have one).
# 2. One teammate should create a new repository (e.g., `MGMT467_TeamX`), set it to **Private**, and add collaborators.
# 3. Each team member should **accept the invite** to the repo.
# 4. Confirm by cloning the repo locally or simply viewing it online.
#
# :bulb: Later labs will rely on this shared repo for collaboration.

# %% [markdown]
# ## 2. Connect Colab to Google Drive

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check contents (optional)
# !ls /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# '0034310343 (1).gdoc'
#  0034310343.gdoc
# '2 5 21.jpeg'
# '2 9 21.jpeg'
#  5x5.gsheet
#  65748192-2064-41C3-9336-2D852C190458.jpeg
#  835F2B73-A5B1-4A8E-B168-AF6FED7849EC.jpeg
# '84.51 Cover Letter.gdoc'
#  9-22-21.gdoc
# 'Academic Conversations.gdoc'
# 'BAIM OPs Notes.gdoc'
#  BroPros.gform
# 'BroPros in house.gdoc'
# 'BroPros (Responses).gsheet'
#  Calendar.gsheet
# 'Cas Description and Goals.gdoc'
# 'Case 2.gdoc'
#  Classroom
# 'Class Schedule .gform'
# 'Coffee and Bagel Bar Alumni meeting.gsheet'
# 'Colab Notebooks'
# 'College Essay #1.gdoc'
# 'Copy of 2k Race Planner.xlsx'
# 'Copy of 500m 2-4-21.m4a'
# 'Copy of BK Document.gdoc'
# 'Copy of BroPros (1).gform'
# 'Copy of BroPros.gform'
# 'Copy of BroPros (Responses).gsheet'
# "Copy of Fall 24' Seniority Tracker.xlsx"
# 'Copy of mach-hommy_-_the_g.a.t._the_gospel_according_to....zip'
# 'Copy of Pokemon TCG Pocket.gsheet'
# 'Copy of Sample Carbon Tech Research Investigation.gdoc'
# "Copy of Spring 24' Seniority Tracker.xlsx"
# 'Copy of Spring 25 Seniority Tracker.xlsx'
# 'CrewOne 8-19.gsheet'
# 'Crew One Bills.gsheet'
# 'CS176 Poject - Initial Report.gdoc'
# 'Cuadra-WA02(Sample).gdoc'
#  D20A990C-443D-494A-BB5F-092F67C41018.jpeg
#  Data.gsheet
# 'Definitely Not KDR Info.gdoc'
#  _DSC6629.jpeg
# 'Ducker Carlisle Cover Letter.gdoc'
# 'Duel Planning Sign Up.gsheet'
# 'Duel Stuff'
# 'Engl 108 First Day of Class.gdoc'
# 'Entm 105 11 14.gdoc'
# 'ENTM 105 11-21.gdoc'
# 'ENTM 105 Final Project - Nathaniel Hiatt.gdoc'
# 'ENTM 105 In Class Assignment 9-12.gdoc'
# 'ENTM 105 - Outline and References.gdoc'
# 'ENTM 105 Week 11 In Class Activity.gdoc'
#  F36000D6-A4F2-48D4-BBAC-CE5B74F0B9A3.jpeg
# 'Fall 24 Signing Day.gdoc'
#  Final2
# 'Finals Week Schedule.gsheet'
#  ❤️.gdoc
# 'Getting started.pdf'
# 'Getting to Know You Assignment_Nathaniel Hiatt.gdoc'
# 'Henley Packing List.gdoc'
# 'Henley Trip.gsheet'
# 'Henley Uni Order Form.gsheet'
# 'Hiatt_Finding Resources Assignment.gdoc'
# 'Hiatt_In Class Assignment.gdoc'
# 'Hiatt_Personal Narrative.gdoc'
# 'Hiatt_Rhetorical Analysis Draft.gdoc'
# 'Hiatt_Rhetoric of Place.gdoc'
# 'hiatt (SGA1, S23).gdoc'
# 'hiatt (SGA2, S23).gdoc'
# 'hiatt (SGA3, S23).gdoc'
# 'hiatt (SGA4, S23).gdoc'
# 'hiatt (SGA5, S23).gdoc'
# 'hiatt (SGA 6, S23).gdoc'
# 'Hiatt_Small Assigment Two.gdoc'
# 'Hiatt_small assignment 10.gdoc'
# 'Hiatt_Small Assignment 4.docx'
# 'Hiatt_Small Assignment 4.gdoc'
# 'Hiatt_Small Assignment 5.gdoc'
# 'Hiatt_Small Assignment 6.gdoc'
# 'Hiatt_Small Assignment 7.gdoc'
# 'Hiatt_Small Assignment 8.gdoc'
# 'Hiatt_Small Assignment One.gdoc'
# 'HW1 Interview.gdoc'
#  image.jpg
# 'IMG_1354 2.jpeg'
#  IMG_3030.jpg
#  IMG_3035.jpg
# 'Internship Emails Texts.gdoc'
# 'JP Morgan Chase Cover Letter.gdoc'
# 'KDR Class of 24 Job Survey.gform'
# 'KDR Class of 24 Job Survey (Responses).gsheet'
# 'KDR Homecoming.gsheet'
# "KDR Parents Weekend Fall '24.gform"
# 'KDR Parents Weekend Fall '\''24 (Responses).gsheet'
# 'Keval Box.gsheet'
# 'Key Concept Packet 4-1--The Enlightenment.docx'
#  List22.gdoc
#  List23.gsheet
# 'List 24.gsheet'
# 'Media Presentation Assignment.gslides'
#  Menu.gdoc
# 'MGMT 254 cheet sheet.gdoc'
# 'MGMT 254 Extra Credit 1 - Nathaniel Hiatt.gdoc'
# 'MGMT 254 Extra Credit 2 - Nathaniel Hiatt.gdoc'
# 'MGMT 361 - Group 11.gdoc'
# 'Mgmt 382 Project One - Team Two.gdoc'
# 'MGMT 42110'
# 'MGMT 467'
# 'MGMT 473 Quiz 3.gdoc'
#  MGMT474
# 'Miebach Cover Letter.gdoc'
# 'Minnesota Duel Planning.gdoc'
# 'MJ DISS TRACK.gdoc'
# 'Nate Big Info.gdoc'
# 'Nathaniel Hiatt_8-24 Marx, "Alienation".gdoc'
# 'Nathaniel Hiatt_Annotation Part 1.gdoc'
# 'Nathaniel Hiatt_Annotation Part 2.gdoc'
# 'Nathaniel Hiatt_Chapter 4 "How the Poor Suffer" .gdoc'
# 'Nathaniel Hiatt_Class Activity 10 (1).gdoc'
# 'Nathaniel Hiatt_Class Activity 10.gdoc'
# 'Nathaniel Hiatt_Class Activity 12.gdoc'
# 'Nathaniel Hiatt_Class Activity 13.gdoc'
# 'Nathaniel Hiatt_Class Activity 1.gdoc'
# 'Nathaniel Hiatt_Class Activity 2.gdoc'
# 'Nathaniel Hiatt_Class Activity 3.gdoc'
# 'Nathaniel Hiatt_Class Activity 5.gdoc'
# 'Nathaniel Hiatt_Class Activity 6.gdoc'
# 'Nathaniel Hiatt_Class Activity 7.gdoc'
# 'Nathaniel Hiatt_Class Activity 8.gdoc'
# 'Nathaniel Hiatt_Crawford, Shop Class.gdoc'
# 'Nathaniel Hiatt_CSW (120-163) Reading Response.gdoc'
# 'Nathaniel Hiatt_CSW (1-39) Reading Response.gdoc'
# 'Nathaniel Hiatt_CSW (40-120) Reading Response.gdoc'
# 'Nathaniel Hiatt_Discipline and Punish, "The Body of the Condemned".gdoc'
# 'Nathaniel Hiatt_Extra Credit.gdoc'
# 'Nathaniel Hiatt_Foucault, Discipline and Punish, "The Panopticon".gdoc'
# 'Nathaniel Hiatt_.gdoc'
# 'Nathaniel Hiatt_molecule of more.gdoc'
# 'Nathaniel Hiatt_Office Space.gdoc'
# 'Nathaniel Hiatt   PHIL 303 Sec 003   Written Assignment #4.gdoc'
# 'Nathaniel Hiatt_ Pollan,This Is Your Mind.gdoc'
# 'Nathaniel Hiatt_Rhetorical Analysis_Final Draft.gdoc'
# 'Nathaniel Hiatt_ Ritzer, McDonaldization.gdoc'
# 'Nathaniel Hiatt_Schweig ch 1-3.gdoc'
# 'Nathaniel Hiatt_Schweig ch 4-6.gdoc'
# 'Nathaniel Hiatt_Sociology in the News 2.gdoc'
# 'Nathaniel Hiatt_Sociology in the News.gdoc'
# 'Nathaniel Hiatt_Strengths Reflection.gdoc'
# 'Nathaniel Hiatt_Thoreau-Life Without Principle.gdoc'
# 'Nathaniel Hiatt_Weber Prodestants.gdoc'
# 'Nathaniel Hiatt_Week2 W: Hochschild, The Managed Heart, ch. 1.gdoc'
# 'Nathaniel Hiatt_Work Behind Our Things Presentation.gslides'
# 'Nathaniel Hiatt_Working Conditions.gdoc'
# 'Nathaniel Hiatt_WP1 Reflection.gdoc'
# 'Nathaniel Hiatt_WP2_Final Draft.gdoc'
# 'Nathaniel Hiatt_WP2_First Draft.gdoc'
# 'Nathaniel Hiatt_WP2_Refelective Memo.gdoc'
# 'Nathaniel Hiatt_WP3_Refelective Memo.gdoc'
# 'Nathaniel Hiatt_WP4_First Draft.gdoc'
# 'Nationals Race Plan.gdoc'
# 'Novice gear size.gform'
# 'OBHR 330 Session 12 HW - Copenhagen 12.gdoc'
# 'OBHR Session 1 HW - Nathaniel Hiatt.gdoc'
# 'OBHR Team Project Deliverable 5 - Nathaniel Hiatt.gdoc'
# 'Order Form - Vmen SB.gsheet'
# 'Parents Weekend Fall 24 - Spending.gsheet'
# 'Parents Weekend.gform'
# 'Parents Weekend (Responses).gsheet'
# 'Peer Review Form_WP1_Scholarly_Article_Analysis(2).gdoc'
# 'PGA 2025.gsheet'
# 'Phil 114 Final Essay | Nathaniel Hiatt.gdoc'
# 'PHIL 114 Small Essay | Nathaniel Hiatt.gdoc'
# 'Phil 303 Assignment 3.gdoc'
# 'Phil 303 Written Assignment 1.gdoc'
# 'Phil 303 Written Assignment #2.gdoc'
# 'Polo Order.gsheet'
#  Portfolio.gslides
# 'Princeton Writing Supplements.gdoc'
# 'Problem Solution Paper.gdoc'
# 'Product Service Description_Nathaniel Hiatt.gdoc'
# 'Purdue 23-24 Budget.gsheet'
# 'Purdue Crew All Team Roster.gsheet'
# 'Purdue Crew JL Inventory.gsheet'
# 'Purdue Crew Officers Board 24-25'
# 'Purdue Crew Polo Form.gform'
# 'Purdue Crew Polo Order - Spring 2025.gsheet'
# 'Purdue Crew President Planning.gdoc'
#  Purdue_Passenger_Van_Training_Certification_Purdue_Passenger_Van_Training__Annual_Certification_Hiatt.pdf
# 'Research Statement - Nathaniel Hiatt.gdoc'
# 'Resume (1).gdoc'
# 'Resume (2).gdoc'
#  Resume.gdoc
#  rocketdashfull.mac.app
#  Schedule.gdoc
# 'SCLA 102 12-5-23.pdf'
#  Score.gsheet
# 'Screen Shot 2021-11-02 at 9.07.56 PM.png'
# 'Session 11 HW.gdoc'
# 'Session 9: Homework 1.gdoc'
# 'Signing Day 9 7 24.gsheet'
# 'Signing Day Betting Shirt Size.gform'
# 'Spring Goals.gdoc'
# 'Summer Plans.gdoc'
# 'Supplemental Essays.gdoc'
# 'Supplement Revisions.gdoc'
# 'Unit One Reflection_Nathaniel Hiatt.gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document.gdoc'
# 'Untitled folder'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form.gform'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'U Washington Major Email.gdoc'
# 'Vmen - Spring Break Package.gsheet'
#  WEB.gslides
#  why.gslides
# 'Womens Head.gsheet'
# 'Work Bibliography.gslides'
# ' Written Assignment #4.docx'
# 'YOU (POEM).gdoc'

# %% [markdown]
# ## 3. Authenticate GCP in Colab

# %%
from google.colab import auth
auth.authenticate_user()

print("Authenticated to GCP successfully!")
# Out:
# Authenticated to GCP successfully!

# %% [markdown]
# Once authenticated, you can access BigQuery and other GCP services from this notebook.

# %% [markdown]
# ## 4. Run a BigQuery Sanity Query

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client(project="mgmt-467-nh")

# Simple test query: public dataset
query = "SELECT name, SUM(number) as total FROM `bigquery-public-data.usa_names.usa_1910_2013` GROUP BY name ORDER BY total DESC LIMIT 5"
results = client.query(query).to_dataframe()

results
# Out:
#       name    total
# 0    James  4942431
# 1     John  4834422
# 2   Robert  4718787
# 3  Michael  4297230
# 4  William  3822209

# %% [markdown]
# ## 5. Save Notebook to GitHub

# %% [markdown]
# To push from Colab to GitHub, you can use a **personal access token (PAT)**.
#
# **Steps:**
# 1. On GitHub, go to **Settings → Developer settings → Personal access tokens (classic)**.
# 2. Generate a token with `repo` permissions (set expiry to ~7 days for safety).
# 3. In Colab, use the snippet below to push your notebook back to GitHub.
#
# :warning: Do **NOT** hardcode tokens in notebooks. Use `getpass` to input securely.

# %%
import os
from getpass import getpass

# Enter your GitHub credentials
username = "hiattn"
token = getpass("Enter Token")
repo = "mgmt476-analytics-portfolio"  # e.g., MGMT467_TeamX
notebook_filename = "Week2_2_Git_Colab_GCP_Lab_NH.ipynb"
target_folder = "Labs" # Specify the target folder within your repository

# Remove the repository directory if it already exists
if os.path.exists(repo):
    # !rm -rf "{repo}"

# Save notebook to GitHub
# !git config --global user.name "{username}"
# !git config --global user.email "{username}@users.noreply.github.com"
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git

# Copy notebook into repo within the target folder
# Use the correct path to the notebook file and the target folder
# !cp "/content/drive/MyDrive/MGMT467/Labs/{notebook_filename}" "{repo}/{target_folder}/"


# Commit and push
# !cd {repo} && git add . && git commit -m "Added Week 2.2 Lab notebook to {target_folder}" && git push
# Out:
# Enter Token··········
# Cloning into 'mgmt476-analytics-portfolio'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 19 (delta 4), reused 4 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 15.76 KiB | 2.63 MiB/s, done.
# Resolving deltas: 100% (4/4), done.
# cp: cannot stat '/content/drive/MyDrive/MGMT467/Labs/Week2_2_Git_Colab_GCP_Lab_NH.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## ✅ Exit Ticket

# %% [markdown]
# Before you leave, make sure you have:
# - [ ] Mounted Google Drive in Colab
# - [ ] Authenticated to GCP successfully
# - [ ] Run the BigQuery sanity check
# - [ ] Saved your notebook to your team GitHub repo
#
# Upload your GitHub repo link to Brightspace as proof of completion.
